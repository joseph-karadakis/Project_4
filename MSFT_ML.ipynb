# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM
from keras.layers import Dropout
import tensorflow as tf

# Read the csv file and clean the data
stock_data = pd.read_csv('Resources/data.csv')
stock_data['Date'] = pd.to_datetime(stock_data['Date'], errors='coerce')
price_columns = ['Close/Last', 'Open', 'High', 'Low']
for column in price_columns:
    stock_data[column] = stock_data[column].str.replace('$', '').astype(float)
msft_data = stock_data[stock_data['Company'] == 'MSFT']
msft_data = msft_data.sort_values(by="Date")

# Time Series Splitting
train_size = int(0.8 * len(msft_data))
train_data = msft_data[:train_size]
test_data = msft_data[train_size:]

# Data Scaling
scaler = MinMaxScaler()
train_data['Close/Last'] = scaler.fit_transform(train_data[['Close/Last']])
test_data['Close/Last'] = scaler.transform(test_data[['Close/Last']])

# Sequence Creation
def create_sequences(data, sequence_length):
    sequences = []
    for i in range(len(data) - sequence_length):
        sequence = data.iloc[i:i+sequence_length]['Close/Last'].values
        target = data.iloc[i+sequence_length]['Close/Last']
        sequences.append((sequence, target))
    return sequences

sequence_length = 60  
train_sequences = create_sequences(train_data, sequence_length)
test_sequences = create_sequences(test_data, sequence_length)

# Convert sequences to numpy arrays
X_train = np.array([seq[0] for seq in train_sequences])
y_train = np.array([seq[1] for seq in train_sequences])
X_test = np.array([seq[0] for seq in test_sequences])
y_test = np.array([seq[1] for seq in test_sequences])

# Model Building
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(sequence_length, 1)))
model.add(Dropout(0.2))
model.add(LSTM(units=50, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=50, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=50))
model.add(Dropout(0.2))
model.add(Dense(units=1))

# Model Compilation
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mean_absolute_error'])

# Model Training
model.fit(X_train, y_train, epochs=70, batch_size=32)

# Model Evaluation
train_loss = model.evaluate(X_train, y_train)
test_loss = model.evaluate(X_test, y_test)
print(f"Training Loss: {train_loss}")
print(f"Testing Loss: {test_loss}")

# Prediction
y_pred = model.predict(X_test)

# Inverse transform scaled predictions to get actual prices
y_pred_actual = scaler.inverse_transform(y_pred)
y_test_actual = scaler.inverse_transform(y_test.reshape(-1, 1))

# Visualization
plt.figure(figsize=(16, 6))
plt.title('MSFT Stock Price Prediction')
plt.plot(test_data['Date'].iloc[sequence_length:], y_test_actual, label='Actual Closing Price')
plt.plot(test_data['Date'].iloc[sequence_length:], y_pred_actual, label='Predicted Closing Price')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Closing Price USD ($)', fontsize=18)
plt.legend()
plt.show()
# Out:
# C:\Users\19517\AppData\Local\Temp\ipykernel_18292\3402333607.py:15: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   stock_data[column] = stock_data[column].str.replace('$', '').astype(float)
# C:\Users\19517\AppData\Local\Temp\ipykernel_18292\3402333607.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data['Close/Last'] = scaler.fit_transform(train_data[['Close/Last']])
# C:\Users\19517\AppData\Local\Temp\ipykernel_18292\3402333607.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data['Close/Last'] = scaler.transform(test_data[['Close/Last']])
# Epoch 1/70
# 61/61 [==============================] - 16s 93ms/step - loss: 0.0147 - mean_absolute_error: 0.0683
# Epoch 2/70
# 61/61 [==============================] - 6s 91ms/step - loss: 0.0021 - mean_absolute_error: 0.0297
# Epoch 3/70
# 61/61 [==============================] - 6s 96ms/step - loss: 0.0020 - mean_absolute_error: 0.0279
# Epoch 4/70
# 61/61 [==============================] - 6s 93ms/step - loss: 0.0024 - mean_absolute_error: 0.0303
# Epoch 5/70
# 61/61 [==============================] - 6s 94ms/step - loss: 0.0018 - mean_absolute_error: 0.0266
# Epoch 6/70
# 61/61 [==============================] - 6s 90ms/step - loss: 0.0015 - mean_absolute_error: 0.0238
# Epoch 7/70
# 61/61 [==============================] - 5s 88ms/step - loss: 0.0021 - mean_absolute_error: 0.0280
# Epoch 8/70
# 61/61 [==============================] - 5s 86ms/step - loss: 0.0017 - mean_absolute_error: 0.0254
# Epoch 9/70
# 61/61 [==============================] - 5s 80ms/step - loss: 0.0015 - mean_absolute_error: 0.0236
# Epoch 10/70
# 61/61 [==============================] - 5s 81ms/step - loss: 0.0015 - mean_absolute_error: 0.0250
# Epoch 11/70
# 61/61 [==============================] - 5s 76ms/step - loss: 0.0018 - mean_absolute_error: 0.0261
# Epoch 12/70
# 61/61 [==============================] - 4s 73ms/step - loss: 0.0014 - mean_absolute_error: 0.0232
# Epoch 13/70
# 61/61 [==============================] - 4s 74ms/step - loss: 0.0014 - mean_absolute_error: 0.0237
# Epoch 14/70
# 61/61 [==============================] - 5s 74ms/step - loss: 0.0016 - mean_absolute_error: 0.0242
# Epoch 15/70
# 61/61 [==============================] - 5s 77ms/step - loss: 0.0013 - mean_absolute_error: 0.0218
# Epoch 16/70
# 61/61 [==============================] - 4s 71ms/step - loss: 0.0014 - mean_absolute_error: 0.0224
# Epoch 17/70
# 61/61 [==============================] - 4s 72ms/step - loss: 0.0012 - mean_absolute_error: 0.0220
# Epoch 18/70
# 61/61 [==============================] - 4s 72ms/step - loss: 0.0011 - mean_absolute_error: 0.0209
# Epoch 19/70
# 61/61 [==============================] - 5s 82ms/step - loss: 0.0011 - mean_absolute_error: 0.0204
# Epoch 20/70
# 61/61 [==============================] - 4s 73ms/step - loss: 0.0012 - mean_absolute_error: 0.0216
# Epoch 21/70
# 61/61 [==============================] - 4s 73ms/step - loss: 0.0012 - mean_absolute_error: 0.0220
# Epoch 22/70
# 61/61 [==============================] - 4s 74ms/step - loss: 0.0011 - mean_absolute_error: 0.0210
# Epoch 23/70
# 61/61 [==============================] - 4s 72ms/step - loss: 0.0012 - mean_absolute_error: 0.0215
# Epoch 24/70
# 61/61 [==============================] - 4s 73ms/step - loss: 0.0012 - mean_absolute_error: 0.0211
# Epoch 25/70
# 61/61 [==============================] - 4s 70ms/step - loss: 0.0011 - mean_absolute_error: 0.0205
# Epoch 26/70
# 61/61 [==============================] - 4s 73ms/step - loss: 0.0011 - mean_absolute_error: 0.0206
# Epoch 27/70
# 61/61 [==============================] - 4s 71ms/step - loss: 0.0012 - mean_absolute_error: 0.0215
# Epoch 28/70
# 61/61 [==============================] - 4s 72ms/step - loss: 0.0011 - mean_absolute_error: 0.0204
# Epoch 29/70
# 61/61 [==============================] - 4s 71ms/step - loss: 0.0010 - mean_absolute_error: 0.0203
# Epoch 30/70
# 61/61 [==============================] - 4s 72ms/step - loss: 0.0010 - mean_absolute_error: 0.0208
# Epoch 31/70
# 61/61 [==============================] - 5s 74ms/step - loss: 0.0013 - mean_absolute_error: 0.0231
# Epoch 32/70
# 61/61 [==============================] - 4s 73ms/step - loss: 0.0011 - mean_absolute_error: 0.0206
# Epoch 33/70
# 61/61 [==============================] - 4s 72ms/step - loss: 9.6805e-04 - mean_absolute_error: 0.0196
# Epoch 34/70
# 61/61 [==============================] - 4s 73ms/step - loss: 9.3434e-04 - mean_absolute_error: 0.0191
# Epoch 35/70
# 61/61 [==============================] - 5s 85ms/step - loss: 9.7989e-04 - mean_absolute_error: 0.0201
# Epoch 36/70
# 61/61 [==============================] - 5s 75ms/step - loss: 0.0010 - mean_absolute_error: 0.0205
# Epoch 37/70
# 61/61 [==============================] - 4s 72ms/step - loss: 8.8948e-04 - mean_absolute_error: 0.0193
# Epoch 38/70
# 61/61 [==============================] - 4s 72ms/step - loss: 9.4564e-04 - mean_absolute_error: 0.0196
# Epoch 39/70
# 61/61 [==============================] - 5s 75ms/step - loss: 9.4121e-04 - mean_absolute_error: 0.0198
# Epoch 40/70
# 61/61 [==============================] - 4s 73ms/step - loss: 9.1765e-04 - mean_absolute_error: 0.0190
# Epoch 41/70
# 61/61 [==============================] - 4s 73ms/step - loss: 9.5373e-04 - mean_absolute_error: 0.0196
# Epoch 42/70
# 61/61 [==============================] - 4s 73ms/step - loss: 7.3938e-04 - mean_absolute_error: 0.0177
# Epoch 43/70
# 61/61 [==============================] - 4s 72ms/step - loss: 8.0722e-04 - mean_absolute_error: 0.0184
# Epoch 44/70
# 61/61 [==============================] - 4s 73ms/step - loss: 0.0010 - mean_absolute_error: 0.0214
# Epoch 45/70
# 61/61 [==============================] - 4s 72ms/step - loss: 0.0010 - mean_absolute_error: 0.0210
# Epoch 46/70
# 61/61 [==============================] - 4s 73ms/step - loss: 8.6939e-04 - mean_absolute_error: 0.0195
# Epoch 47/70
# 61/61 [==============================] - 4s 72ms/step - loss: 8.2202e-04 - mean_absolute_error: 0.0192
# Epoch 48/70
# 61/61 [==============================] - 4s 72ms/step - loss: 0.0010 - mean_absolute_error: 0.0199
# Epoch 49/70
# 61/61 [==============================] - 4s 71ms/step - loss: 0.0011 - mean_absolute_error: 0.0211
# Epoch 50/70
# 61/61 [==============================] - 4s 74ms/step - loss: 8.1618e-04 - mean_absolute_error: 0.0190
# Epoch 51/70
# 61/61 [==============================] - 4s 72ms/step - loss: 8.4697e-04 - mean_absolute_error: 0.0188
# Epoch 52/70
# 61/61 [==============================] - 4s 73ms/step - loss: 9.2745e-04 - mean_absolute_error: 0.0201
# Epoch 53/70
# 61/61 [==============================] - 4s 72ms/step - loss: 8.7694e-04 - mean_absolute_error: 0.0191
# Epoch 54/70
# 61/61 [==============================] - 4s 73ms/step - loss: 8.4700e-04 - mean_absolute_error: 0.0188
# Epoch 55/70
# 61/61 [==============================] - 4s 72ms/step - loss: 0.0011 - mean_absolute_error: 0.0216
# Epoch 56/70
# 61/61 [==============================] - 4s 71ms/step - loss: 6.7881e-04 - mean_absolute_error: 0.0177
# Epoch 57/70
# 61/61 [==============================] - 4s 71ms/step - loss: 7.6786e-04 - mean_absolute_error: 0.0184
# Epoch 58/70
# 61/61 [==============================] - 4s 73ms/step - loss: 7.9348e-04 - mean_absolute_error: 0.0189
# Epoch 59/70
# 61/61 [==============================] - 4s 73ms/step - loss: 8.2116e-04 - mean_absolute_error: 0.0194
# Epoch 60/70
# 61/61 [==============================] - 4s 73ms/step - loss: 7.0748e-04 - mean_absolute_error: 0.0179
# Epoch 61/70
# 61/61 [==============================] - 4s 72ms/step - loss: 8.7038e-04 - mean_absolute_error: 0.0193
# Epoch 62/70
# 61/61 [==============================] - 4s 72ms/step - loss: 7.4324e-04 - mean_absolute_error: 0.0187
# Epoch 63/70
# 61/61 [==============================] - 4s 71ms/step - loss: 8.4594e-04 - mean_absolute_error: 0.0195
# Epoch 64/70
# 61/61 [==============================] - 4s 71ms/step - loss: 7.0894e-04 - mean_absolute_error: 0.0180
# Epoch 65/70
# 61/61 [==============================] - 4s 72ms/step - loss: 6.9982e-04 - mean_absolute_error: 0.0178
# Epoch 66/70
# 61/61 [==============================] - 4s 72ms/step - loss: 7.9979e-04 - mean_absolute_error: 0.0187
# Epoch 67/70
# 61/61 [==============================] - 4s 73ms/step - loss: 8.7767e-04 - mean_absolute_error: 0.0198
# Epoch 68/70
# 61/61 [==============================] - 4s 71ms/step - loss: 8.1143e-04 - mean_absolute_error: 0.0195
# Epoch 69/70
# 61/61 [==============================] - 4s 72ms/step - loss: 7.4476e-04 - mean_absolute_error: 0.0186
# Epoch 70/70
# 61/61 [==============================] - 4s 72ms/step - loss: 7.2793e-04 - mean_absolute_error: 0.0186
# 61/61 [==============================] - 3s 28ms/step - loss: 2.8018e-04 - mean_absolute_error: 0.0136
# 14/14 [==============================] - 2s 27ms/step - loss: 0.0033 - mean_absolute_error: 0.0456
# Training Loss: [0.0002801780356094241, 0.01357568521052599]
# Testing Loss: [0.0033044563606381416, 0.04564139246940613]
# 14/14 [==============================] - 2s 27ms/step

# %%
# Plotting the close price history (for the entire timeframe)
plt.figure(figsize=(16,6))
plt.title('MSFT Close Price History')
plt.plot(msft_data['Date'], msft_data['Close/Last'])
plt.xlabel('Date', fontsize=18)
plt.ylabel('CLose Price USD ($)', fontsize=18)
plt.show()
