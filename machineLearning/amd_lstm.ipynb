# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM
from keras.layers import Dropout
import tensorflow as tf

# Read the csv file and clean the data
stock_data = pd.read_csv('../dataCleaning/data.csv')
stock_data['Date'] = pd.to_datetime(stock_data['Date'], errors='coerce')
price_columns = ['Close/Last', 'Open', 'High', 'Low']
for column in price_columns:
    stock_data[column] = stock_data[column].str.replace('$', '').astype(float)
AMD_data = stock_data[stock_data['Company'] == 'AMD']
AMD_data = AMD_data.sort_values(by="Date")

# Time Series Splitting
train_size = int(0.8 * len(AMD_data))
train_data = AMD_data[:train_size]
test_data = AMD_data[train_size:]

# Data Scaling
scaler = MinMaxScaler()
train_data['Close/Last'] = scaler.fit_transform(train_data[['Close/Last']])
test_data['Close/Last'] = scaler.transform(test_data[['Close/Last']])

# Sequence Creation
def create_sequences(data, sequence_length):
    sequences = []
    for i in range(len(data) - sequence_length):
        sequence = data.iloc[i:i+sequence_length]['Close/Last'].values
        target = data.iloc[i+sequence_length]['Close/Last']
        sequences.append((sequence, target))
    return sequences

sequence_length = 60  
train_sequences = create_sequences(train_data, sequence_length)
test_sequences = create_sequences(test_data, sequence_length)

# Convert sequences to numpy arrays
X_train = np.array([seq[0] for seq in train_sequences])
y_train = np.array([seq[1] for seq in train_sequences])
X_test = np.array([seq[0] for seq in test_sequences])
y_test = np.array([seq[1] for seq in test_sequences])

# Model Building
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(sequence_length, 1)))
model.add(Dropout(0.2))
model.add(LSTM(units=50, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=50, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=50))
model.add(Dropout(0.2))
model.add(Dense(units=1))

# Model Compilation
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mean_absolute_error'])

# Model Training
model.fit(X_train, y_train, epochs=70, batch_size=32)

# Model Evaluation
train_loss = model.evaluate(X_train, y_train)
test_loss = model.evaluate(X_test, y_test)
print(f"Training Loss: {train_loss}")
print(f"Testing Loss: {test_loss}")

# Prediction
y_pred = model.predict(X_test)

# Inverse transform scaled predictions to get actual prices
y_pred_actual = scaler.inverse_transform(y_pred)
y_test_actual = scaler.inverse_transform(y_test.reshape(-1, 1))

# Visualization
plt.figure(figsize=(16, 6))
plt.title('AMD Stock Price Prediction')
plt.plot(test_data['Date'].iloc[sequence_length:], y_test_actual, label='Actual Closing Price')
plt.plot(test_data['Date'].iloc[sequence_length:], y_pred_actual, label='Predicted Closing Price')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Closing Price USD ($)', fontsize=18)
plt.legend()
plt.show()
# Out:
# C:\Users\Kha Nguyen\AppData\Local\Temp\ipykernel_16608\874647260.py:15: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   stock_data[column] = stock_data[column].str.replace('$', '').astype(float)
# C:\Users\Kha Nguyen\AppData\Local\Temp\ipykernel_16608\874647260.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data['Close/Last'] = scaler.fit_transform(train_data[['Close/Last']])
# C:\Users\Kha Nguyen\AppData\Local\Temp\ipykernel_16608\874647260.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data['Close/Last'] = scaler.transform(test_data[['Close/Last']])
# Epoch 1/70
# 61/61 [==============================] - 6s 45ms/step - loss: 0.0119 - mean_absolute_error: 0.0565
# Epoch 2/70
# 61/61 [==============================] - 3s 43ms/step - loss: 0.0029 - mean_absolute_error: 0.0301
# Epoch 3/70
# 61/61 [==============================] - 3s 43ms/step - loss: 0.0023 - mean_absolute_error: 0.0267
# Epoch 4/70
# 61/61 [==============================] - 3s 43ms/step - loss: 0.0025 - mean_absolute_error: 0.0288
# Epoch 5/70
# 61/61 [==============================] - 3s 42ms/step - loss: 0.0032 - mean_absolute_error: 0.0325
# Epoch 6/70
# 61/61 [==============================] - 3s 43ms/step - loss: 0.0022 - mean_absolute_error: 0.0280
# Epoch 7/70
# 61/61 [==============================] - 3s 42ms/step - loss: 0.0023 - mean_absolute_error: 0.0280
# Epoch 8/70
# 61/61 [==============================] - 3s 42ms/step - loss: 0.0025 - mean_absolute_error: 0.0292
# Epoch 9/70
# 61/61 [==============================] - 3s 43ms/step - loss: 0.0022 - mean_absolute_error: 0.0278
# Epoch 10/70
# 61/61 [==============================] - 3s 43ms/step - loss: 0.0020 - mean_absolute_error: 0.0258
# Epoch 11/70
# 61/61 [==============================] - 3s 44ms/step - loss: 0.0020 - mean_absolute_error: 0.0261
# Epoch 12/70
# 61/61 [==============================] - 3s 42ms/step - loss: 0.0017 - mean_absolute_error: 0.0238
# Epoch 13/70
# 61/61 [==============================] - 3s 42ms/step - loss: 0.0020 - mean_absolute_error: 0.0254
# Epoch 14/70
# 61/61 [==============================] - 2s 41ms/step - loss: 0.0017 - mean_absolute_error: 0.0245
# Epoch 15/70
# 61/61 [==============================] - 3s 41ms/step - loss: 0.0017 - mean_absolute_error: 0.0236
# Epoch 16/70
# 61/61 [==============================] - 3s 44ms/step - loss: 0.0016 - mean_absolute_error: 0.0232
# Epoch 17/70
# 61/61 [==============================] - 3s 45ms/step - loss: 0.0017 - mean_absolute_error: 0.0254
# Epoch 18/70
# 61/61 [==============================] - 3s 44ms/step - loss: 0.0017 - mean_absolute_error: 0.0246
# Epoch 19/70
# 61/61 [==============================] - 3s 42ms/step - loss: 0.0017 - mean_absolute_error: 0.0247
# Epoch 20/70
# 61/61 [==============================] - 3s 42ms/step - loss: 0.0014 - mean_absolute_error: 0.0225
# Epoch 21/70
# 61/61 [==============================] - 3s 42ms/step - loss: 0.0014 - mean_absolute_error: 0.0222
# Epoch 22/70
# 61/61 [==============================] - 3s 42ms/step - loss: 0.0015 - mean_absolute_error: 0.0230
# Epoch 23/70
# 61/61 [==============================] - 3s 42ms/step - loss: 0.0014 - mean_absolute_error: 0.0223
# Epoch 24/70
# 61/61 [==============================] - 3s 42ms/step - loss: 0.0016 - mean_absolute_error: 0.0240
# Epoch 25/70
# 61/61 [==============================] - 3s 42ms/step - loss: 0.0017 - mean_absolute_error: 0.0251
# Epoch 26/70
# 61/61 [==============================] - 3s 42ms/step - loss: 0.0014 - mean_absolute_error: 0.0227
# Epoch 27/70
# 61/61 [==============================] - 3s 42ms/step - loss: 0.0014 - mean_absolute_error: 0.0225
# Epoch 28/70
# 61/61 [==============================] - 3s 42ms/step - loss: 0.0013 - mean_absolute_error: 0.0219
# Epoch 29/70
# 61/61 [==============================] - 3s 42ms/step - loss: 0.0020 - mean_absolute_error: 0.0269
# Epoch 30/70
# 61/61 [==============================] - 3s 42ms/step - loss: 0.0013 - mean_absolute_error: 0.0220
# Epoch 31/70
# 61/61 [==============================] - 3s 42ms/step - loss: 0.0012 - mean_absolute_error: 0.0210
# Epoch 32/70
# 61/61 [==============================] - 3s 42ms/step - loss: 0.0013 - mean_absolute_error: 0.0223
# Epoch 33/70
# 61/61 [==============================] - 3s 42ms/step - loss: 0.0015 - mean_absolute_error: 0.0230
# Epoch 34/70
# 61/61 [==============================] - 3s 42ms/step - loss: 0.0017 - mean_absolute_error: 0.0243
# Epoch 35/70
# 61/61 [==============================] - 3s 42ms/step - loss: 0.0015 - mean_absolute_error: 0.0233
# Epoch 36/70
# 61/61 [==============================] - 3s 42ms/step - loss: 0.0013 - mean_absolute_error: 0.0220
# Epoch 37/70
# 61/61 [==============================] - 3s 42ms/step - loss: 0.0013 - mean_absolute_error: 0.0223
# Epoch 38/70
# 61/61 [==============================] - 3s 42ms/step - loss: 0.0013 - mean_absolute_error: 0.0227
# Epoch 39/70
# 61/61 [==============================] - 3s 42ms/step - loss: 0.0014 - mean_absolute_error: 0.0228
# Epoch 40/70
# 61/61 [==============================] - 3s 42ms/step - loss: 0.0011 - mean_absolute_error: 0.0215
# Epoch 41/70
# 61/61 [==============================] - 3s 42ms/step - loss: 0.0011 - mean_absolute_error: 0.0215
# Epoch 42/70
# 61/61 [==============================] - 3s 42ms/step - loss: 0.0011 - mean_absolute_error: 0.0210
# Epoch 43/70
# 61/61 [==============================] - 3s 42ms/step - loss: 0.0011 - mean_absolute_error: 0.0209
# Epoch 44/70
# 61/61 [==============================] - 3s 42ms/step - loss: 0.0012 - mean_absolute_error: 0.0219
# Epoch 45/70
# 61/61 [==============================] - 3s 42ms/step - loss: 0.0013 - mean_absolute_error: 0.0223
# Epoch 46/70
# 61/61 [==============================] - 3s 42ms/step - loss: 0.0012 - mean_absolute_error: 0.0220
# Epoch 47/70
# 61/61 [==============================] - 3s 43ms/step - loss: 0.0013 - mean_absolute_error: 0.0221
# Epoch 48/70
# 61/61 [==============================] - 3s 42ms/step - loss: 0.0011 - mean_absolute_error: 0.0214
# Epoch 49/70
# 61/61 [==============================] - 3s 42ms/step - loss: 0.0010 - mean_absolute_error: 0.0207
# Epoch 50/70
# 61/61 [==============================] - 3s 42ms/step - loss: 0.0012 - mean_absolute_error: 0.0222
# Epoch 51/70
# 61/61 [==============================] - 3s 43ms/step - loss: 0.0012 - mean_absolute_error: 0.0213
# Epoch 52/70
# 61/61 [==============================] - 3s 42ms/step - loss: 0.0013 - mean_absolute_error: 0.0231
# Epoch 53/70
# 61/61 [==============================] - 3s 42ms/step - loss: 0.0012 - mean_absolute_error: 0.0216
# Epoch 54/70
# 61/61 [==============================] - 3s 43ms/step - loss: 0.0012 - mean_absolute_error: 0.0219
# Epoch 55/70
# 61/61 [==============================] - 3s 43ms/step - loss: 0.0012 - mean_absolute_error: 0.0224
# Epoch 56/70
# 61/61 [==============================] - 3s 43ms/step - loss: 0.0013 - mean_absolute_error: 0.0223
# Epoch 57/70
# 61/61 [==============================] - 3s 42ms/step - loss: 0.0011 - mean_absolute_error: 0.0209
# Epoch 58/70
# 61/61 [==============================] - 3s 42ms/step - loss: 0.0011 - mean_absolute_error: 0.0212
# Epoch 59/70
# 61/61 [==============================] - 3s 43ms/step - loss: 0.0011 - mean_absolute_error: 0.0216
# Epoch 60/70
# 61/61 [==============================] - 3s 42ms/step - loss: 0.0012 - mean_absolute_error: 0.0213
# Epoch 61/70
# 61/61 [==============================] - 3s 42ms/step - loss: 0.0010 - mean_absolute_error: 0.0210
# Epoch 62/70
# 61/61 [==============================] - 3s 42ms/step - loss: 9.6006e-04 - mean_absolute_error: 0.0204
# Epoch 63/70
# 61/61 [==============================] - 3s 43ms/step - loss: 9.3798e-04 - mean_absolute_error: 0.0198
# Epoch 64/70
# 61/61 [==============================] - 3s 42ms/step - loss: 9.6512e-04 - mean_absolute_error: 0.0199
# Epoch 65/70
# 61/61 [==============================] - 3s 42ms/step - loss: 0.0011 - mean_absolute_error: 0.0216
# Epoch 66/70
# 61/61 [==============================] - 3s 42ms/step - loss: 0.0010 - mean_absolute_error: 0.0202
# Epoch 67/70
# 61/61 [==============================] - 3s 42ms/step - loss: 0.0010 - mean_absolute_error: 0.0201
# Epoch 68/70
# 61/61 [==============================] - 3s 42ms/step - loss: 0.0011 - mean_absolute_error: 0.0215
# Epoch 69/70
# 61/61 [==============================] - 3s 42ms/step - loss: 0.0011 - mean_absolute_error: 0.0210
# Epoch 70/70
# 61/61 [==============================] - 3s 42ms/step - loss: 9.9398e-04 - mean_absolute_error: 0.0202
# 61/61 [==============================] - 2s 17ms/step - loss: 2.7481e-04 - mean_absolute_error: 0.0094
# 14/14 [==============================] - 1s 17ms/step - loss: 0.0295 - mean_absolute_error: 0.1096
# Training Loss: [0.00027481140568852425, 0.009351770393550396]
# Testing Loss: [0.029487814754247665, 0.10960257798433304]
# 14/14 [==============================] - 1s 17ms/step
